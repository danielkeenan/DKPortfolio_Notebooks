# %% [markdown]
# # Top 5000 Music Albums

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('rym_top_5000_all_time.csv')
df
# Out:
#       Ranking                                         Album  \
# 0         1.0                                   OK Computer
# 1         2.0                            Wish You Were Here
# 2         3.0              In the Court of the Crimson King
# 3         4.0                                         Kid A
# 4         5.0                           To Pimp a Butterfly
# ...       ...                                           ...
# 4995   4996.0                                     Gracious!
# 4996   4997.0                          Knights of the Cross
# 4997   4998.0             (Listen For) The Rag and Bone Man
# 4998   4999.0  Hymnen für elektronische und konkrete Klänge
# 4999   5000.0                        Adventures in Paradise
#
#                                             Artist Name       Release Date  \
# 0                                             Radiohead       16 June 1997
# 1                                            Pink Floyd  12 September 1975
# 2                                          King Crimson    10 October 1969
# 3                                             Radiohead     3 October 2000
# 4                                        Kendrick Lamar      15 March 2015
# ...                                                 ...                ...
# 4995                                           Gracious       17 July 1970
# 4996                                       Grave Digger        18 May 1998
# 4997                                 And Also the Trees   12 November 2007
# 4998  Studio für elektronische Musik des Westdeutsch...               1969
# 4999                                    Minnie Riperton        22 May 1975
#
#                                                Genres  \
# 0                          Alternative Rock, Art Rock
# 1                          Progressive Rock, Art Rock
# 2                          Progressive Rock, Art Rock
# 3             Art Rock, Experimental Rock, Electronic
# 4     Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
# ...                                               ...
# 4995                 Progressive Rock, Symphonic Prog
# 4996                         Power Metal, Heavy Metal
# 4997                                         Art Rock
# 4998   Musique concrète, Modern Classical, Electronic
# 4999                            Smooth Soul, Pop Soul
#
#                                             Descriptors  Average Rating  \
# 0     melancholic, anxious, futuristic, alienation, ...            4.23
# 1     melancholic, atmospheric, progressive, male vo...            4.29
# 2     fantasy, epic, progressive, philosophical, com...            4.30
# 3     cold, melancholic, futuristic, atmospheric, an...            4.21
# 4     political, conscious, poetic, protest, concept...            4.27
# ...                                                 ...             ...
# 4995                                                NaN            3.69
# 4996  history, male vocals, heavy, concept album, an...            3.67
# 4997  atmospheric, poetic, dark, male vocals, ominou...            3.68
# 4998  avant-garde, sampling, dense, complex, scary, ...            3.65
# 4999  lush, female vocals, romantic, uplifting, summ...            3.69
#
#      Number of Ratings  Number of Reviews
# 0               70,382               1531
# 1               48,662                983
# 2               44,943                870
# 3               58,590                734
# 4               44,206                379
# ...                ...                ...
# 4995               565                 32
# 4996               562                 11
# 4997               524                 15
# 4998               536                 11
# 4999               490                 14
#
# [5000 rows x 9 columns]

# %%
df.shape
# Out:
# (5000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ranking            5000 non-null   float64
#  1   Album              5000 non-null   object
#  2   Artist Name        5000 non-null   object
#  3   Release Date       5000 non-null   object
#  4   Genres             5000 non-null   object
#  5   Descriptors        4886 non-null   object
#  6   Average Rating     5000 non-null   float64
#  7   Number of Ratings  5000 non-null   object
#  8   Number of Reviews  5000 non-null   int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 351.7+ KB

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'])
df
# Out:
#       Ranking                                         Album  \
# 0         1.0                                   OK Computer
# 1         2.0                            Wish You Were Here
# 2         3.0              In the Court of the Crimson King
# 3         4.0                                         Kid A
# 4         5.0                           To Pimp a Butterfly
# ...       ...                                           ...
# 4995   4996.0                                     Gracious!
# 4996   4997.0                          Knights of the Cross
# 4997   4998.0             (Listen For) The Rag and Bone Man
# 4998   4999.0  Hymnen für elektronische und konkrete Klänge
# 4999   5000.0                        Adventures in Paradise
#
#                                             Artist Name Release Date  \
# 0                                             Radiohead   1997-06-16
# 1                                            Pink Floyd   1975-09-12
# 2                                          King Crimson   1969-10-10
# 3                                             Radiohead   2000-10-03
# 4                                        Kendrick Lamar   2015-03-15
# ...                                                 ...          ...
# 4995                                           Gracious   1970-07-17
# 4996                                       Grave Digger   1998-05-18
# 4997                                 And Also the Trees   2007-11-12
# 4998  Studio für elektronische Musik des Westdeutsch...   1969-01-01
# 4999                                    Minnie Riperton   1975-05-22
#
#                                                Genres  \
# 0                          Alternative Rock, Art Rock
# 1                          Progressive Rock, Art Rock
# 2                          Progressive Rock, Art Rock
# 3             Art Rock, Experimental Rock, Electronic
# 4     Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
# ...                                               ...
# 4995                 Progressive Rock, Symphonic Prog
# 4996                         Power Metal, Heavy Metal
# 4997                                         Art Rock
# 4998   Musique concrète, Modern Classical, Electronic
# 4999                            Smooth Soul, Pop Soul
#
#                                             Descriptors  Average Rating  \
# 0     melancholic, anxious, futuristic, alienation, ...            4.23
# 1     melancholic, atmospheric, progressive, male vo...            4.29
# 2     fantasy, epic, progressive, philosophical, com...            4.30
# 3     cold, melancholic, futuristic, atmospheric, an...            4.21
# 4     political, conscious, poetic, protest, concept...            4.27
# ...                                                 ...             ...
# 4995                                                NaN            3.69
# 4996  history, male vocals, heavy, concept album, an...            3.67
# 4997  atmospheric, poetic, dark, male vocals, ominou...            3.68
# 4998  avant-garde, sampling, dense, complex, scary, ...            3.65
# 4999  lush, female vocals, romantic, uplifting, summ...            3.69
#
#      Number of Ratings  Number of Reviews
# 0               70,382               1531
# 1               48,662                983
# 2               44,943                870
# 3               58,590                734
# 4               44,206                379
# ...                ...                ...
# 4995               565                 32
# 4996               562                 11
# 4997               524                 15
# 4998               536                 11
# 4999               490                 14
#
# [5000 rows x 9 columns]

# %%
df['Release Month'] = df['Release Date'].dt.month
df['Release Year'] = df['Release Date'].dt.year
df['Release Decade'] = df['Release Year'] // 10 * 10
df = df.drop('Release Date', axis=1)
df
# Out:
#       Ranking                                         Album  \
# 0         1.0                                   OK Computer
# 1         2.0                            Wish You Were Here
# 2         3.0              In the Court of the Crimson King
# 3         4.0                                         Kid A
# 4         5.0                           To Pimp a Butterfly
# ...       ...                                           ...
# 4995   4996.0                                     Gracious!
# 4996   4997.0                          Knights of the Cross
# 4997   4998.0             (Listen For) The Rag and Bone Man
# 4998   4999.0  Hymnen für elektronische und konkrete Klänge
# 4999   5000.0                        Adventures in Paradise
#
#                                             Artist Name  \
# 0                                             Radiohead
# 1                                            Pink Floyd
# 2                                          King Crimson
# 3                                             Radiohead
# 4                                        Kendrick Lamar
# ...                                                 ...
# 4995                                           Gracious
# 4996                                       Grave Digger
# 4997                                 And Also the Trees
# 4998  Studio für elektronische Musik des Westdeutsch...
# 4999                                    Minnie Riperton
#
#                                                Genres  \
# 0                          Alternative Rock, Art Rock
# 1                          Progressive Rock, Art Rock
# 2                          Progressive Rock, Art Rock
# 3             Art Rock, Experimental Rock, Electronic
# 4     Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
# ...                                               ...
# 4995                 Progressive Rock, Symphonic Prog
# 4996                         Power Metal, Heavy Metal
# 4997                                         Art Rock
# 4998   Musique concrète, Modern Classical, Electronic
# 4999                            Smooth Soul, Pop Soul
#
#                                             Descriptors  Average Rating  \
# 0     melancholic, anxious, futuristic, alienation, ...            4.23
# 1     melancholic, atmospheric, progressive, male vo...            4.29
# 2     fantasy, epic, progressive, philosophical, com...            4.30
# 3     cold, melancholic, futuristic, atmospheric, an...            4.21
# 4     political, conscious, poetic, protest, concept...            4.27
# ...                                                 ...             ...
# 4995                                                NaN            3.69
# 4996  history, male vocals, heavy, concept album, an...            3.67
# 4997  atmospheric, poetic, dark, male vocals, ominou...            3.68
# 4998  avant-garde, sampling, dense, complex, scary, ...            3.65
# 4999  lush, female vocals, romantic, uplifting, summ...            3.69
#
#      Number of Ratings  Number of Reviews  Release Month  Release Year  \
# 0               70,382               1531              6          1997
# 1               48,662                983              9          1975
# 2               44,943                870             10          1969
# 3               58,590                734             10          2000
# 4               44,206                379              3          2015
# ...                ...                ...            ...           ...
# 4995               565                 32              7          1970
# 4996               562                 11              5          1998
# 4997               524                 15             11          2007
# 4998               536                 11              1          1969
# 4999               490                 14              5          1975
#
#       Release Decade
# 0               1990
# 1               1970
# 2               1960
# 3               2000
# 4               2010
# ...              ...
# 4995            1970
# 4996            1990
# 4997            2000
# 4998            1960
# 4999            1970
#
# [5000 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# Ranking                0
# Album                  0
# Artist Name            0
# Genres                 0
# Descriptors          114
# Average Rating         0
# Number of Ratings      0
# Number of Reviews      0
# Release Month          0
# Release Year           0
# Release Decade         0
# dtype: int64

# %%
df = df.drop('Descriptors', axis=1)
df
# Out:
#       Ranking                                         Album  \
# 0         1.0                                   OK Computer
# 1         2.0                            Wish You Were Here
# 2         3.0              In the Court of the Crimson King
# 3         4.0                                         Kid A
# 4         5.0                           To Pimp a Butterfly
# ...       ...                                           ...
# 4995   4996.0                                     Gracious!
# 4996   4997.0                          Knights of the Cross
# 4997   4998.0             (Listen For) The Rag and Bone Man
# 4998   4999.0  Hymnen für elektronische und konkrete Klänge
# 4999   5000.0                        Adventures in Paradise
#
#                                             Artist Name  \
# 0                                             Radiohead
# 1                                            Pink Floyd
# 2                                          King Crimson
# 3                                             Radiohead
# 4                                        Kendrick Lamar
# ...                                                 ...
# 4995                                           Gracious
# 4996                                       Grave Digger
# 4997                                 And Also the Trees
# 4998  Studio für elektronische Musik des Westdeutsch...
# 4999                                    Minnie Riperton
#
#                                                Genres  Average Rating  \
# 0                          Alternative Rock, Art Rock            4.23
# 1                          Progressive Rock, Art Rock            4.29
# 2                          Progressive Rock, Art Rock            4.30
# 3             Art Rock, Experimental Rock, Electronic            4.21
# 4     Conscious Hip Hop, West Coast Hip Hop, Jazz Rap            4.27
# ...                                               ...             ...
# 4995                 Progressive Rock, Symphonic Prog            3.69
# 4996                         Power Metal, Heavy Metal            3.67
# 4997                                         Art Rock            3.68
# 4998   Musique concrète, Modern Classical, Electronic            3.65
# 4999                            Smooth Soul, Pop Soul            3.69
#
#      Number of Ratings  Number of Reviews  Release Month  Release Year  \
# 0               70,382               1531              6          1997
# 1               48,662                983              9          1975
# 2               44,943                870             10          1969
# 3               58,590                734             10          2000
# 4               44,206                379              3          2015
# ...                ...                ...            ...           ...
# 4995               565                 32              7          1970
# 4996               562                 11              5          1998
# 4997               524                 15             11          2007
# 4998               536                 11              1          1969
# 4999               490                 14              5          1975
#
#       Release Decade
# 0               1990
# 1               1970
# 2               1960
# 3               2000
# 4               2010
# ...              ...
# 4995            1970
# 4996            1990
# 4997            2000
# 4998            1960
# 4999            1970
#
# [5000 rows x 10 columns]

# %%
df[['Genre 1', 'Genre 2', 'Genre 3', 'Genre 4', 'Genre 5']] = df['Genres'].str.split(',', expand=True)
df = df.drop('Genres', axis=1)
df
# Out:
#       Ranking                                         Album  \
# 0         1.0                                   OK Computer
# 1         2.0                            Wish You Were Here
# 2         3.0              In the Court of the Crimson King
# 3         4.0                                         Kid A
# 4         5.0                           To Pimp a Butterfly
# ...       ...                                           ...
# 4995   4996.0                                     Gracious!
# 4996   4997.0                          Knights of the Cross
# 4997   4998.0             (Listen For) The Rag and Bone Man
# 4998   4999.0  Hymnen für elektronische und konkrete Klänge
# 4999   5000.0                        Adventures in Paradise
#
#                                             Artist Name  Average Rating  \
# 0                                             Radiohead            4.23
# 1                                            Pink Floyd            4.29
# 2                                          King Crimson            4.30
# 3                                             Radiohead            4.21
# 4                                        Kendrick Lamar            4.27
# ...                                                 ...             ...
# 4995                                           Gracious            3.69
# 4996                                       Grave Digger            3.67
# 4997                                 And Also the Trees            3.68
# 4998  Studio für elektronische Musik des Westdeutsch...            3.65
# 4999                                    Minnie Riperton            3.69
#
#      Number of Ratings  Number of Reviews  Release Month  Release Year  \
# 0               70,382               1531              6          1997
# 1               48,662                983              9          1975
# 2               44,943                870             10          1969
# 3               58,590                734             10          2000
# 4               44,206                379              3          2015
# ...                ...                ...            ...           ...
# 4995               565                 32              7          1970
# 4996               562                 11              5          1998
# 4997               524                 15             11          2007
# 4998               536                 11              1          1969
# 4999               490                 14              5          1975
#
#       Release Decade            Genre 1              Genre 2      Genre 3  \
# 0               1990   Alternative Rock             Art Rock         None
# 1               1970   Progressive Rock             Art Rock         None
# 2               1960   Progressive Rock             Art Rock         None
# 3               2000           Art Rock    Experimental Rock   Electronic
# 4               2010  Conscious Hip Hop   West Coast Hip Hop     Jazz Rap
# ...              ...                ...                  ...          ...
# 4995            1970   Progressive Rock       Symphonic Prog         None
# 4996            1990        Power Metal          Heavy Metal         None
# 4997            2000           Art Rock                 None         None
# 4998            1960   Musique concrète     Modern Classical   Electronic
# 4999            1970        Smooth Soul             Pop Soul         None
#
#      Genre 4 Genre 5
# 0       None    None
# 1       None    None
# 2       None    None
# 3       None    None
# 4       None    None
# ...      ...     ...
# 4995    None    None
# 4996    None    None
# 4997    None    None
# 4998    None    None
# 4999    None    None
#
# [5000 rows x 14 columns]

# %% [markdown]
# ### Top Albums by Date

# %%
plt.figure(figsize=(14,10))
sns.countplot(x=df['Release Year'],color='MediumSeaGreen')
plt.title('Number of Albums Released by Year',  fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.xticks(rotation = 90)

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.countplot(x=df['Release Decade'], color='SlateBlue')
plt.title('Number of Albums Released by Decade', fontsize=20)
plt.xlabel('Decade', fontsize=15)
plt.ylabel('Album Count', fontsize=15)

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.countplot(x=df['Release Month'], color='Tomato')
plt.title('Number of Albums Released by Month', fontsize=20)
plt.xlabel('Month', fontsize=15)
plt.ylabel('Album Count', fontsize=15)

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)

# %% [markdown]
# ### Top Genres by Decade

# %%
df_1970 = df[df['Release Year'].between(1970, 1979)]
df_1970
# Out:
#       Ranking                                              Album  \
# 1         2.0                                 Wish You Were Here
# 6         7.0                          The Dark Side of the Moon
# 9        10.0  The Rise and Fall of Ziggy Stardust and the Sp...
# 17       18.0                                           Paranoid
# 25       26.0                                                Red
# ...       ...                                                ...
# 4983   4984.0                                    Racional vol. 2
# 4985   4986.0                            Visions of Dennis Brown
# 4991   4992.0                                               I Am
# 4995   4996.0                                          Gracious!
# 4999   5000.0                             Adventures in Paradise
#
#              Artist Name  Average Rating Number of Ratings  Number of Reviews  \
# 1             Pink Floyd            4.29            48,662                983
# 6             Pink Floyd            4.20            57,622               1549
# 9            David Bowie            4.26            39,501                721
# 17         Black Sabbath            4.19            35,870                582
# 25          King Crimson            4.21            23,525                405
# ...                  ...             ...               ...                ...
# 4983            Tim Maia            3.69               542                  5
# 4985        Dennis Brown            3.71               312                 12
# 4991  Earth, Wind & Fire            3.68             1,108                 22
# 4995            Gracious            3.69               565                 32
# 4999     Minnie Riperton            3.69               490                 14
#
#       Release Month  Release Year  Release Decade           Genre 1  \
# 1                 9          1975            1970  Progressive Rock
# 6                 3          1973            1970          Art Rock
# 9                 6          1972            1970         Glam Rock
# 17                9          1970            1970       Heavy Metal
# 25               10          1974            1970  Progressive Rock
# ...             ...           ...             ...               ...
# 4983              1          1975            1970              Funk
# 4985              1          1978            1970      Roots Reggae
# 4991              6          1979            1970             Disco
# 4995              7          1970            1970  Progressive Rock
# 4999              5          1975            1970       Smooth Soul
#
#                 Genre 2 Genre 3 Genre 4 Genre 5
# 1              Art Rock    None    None    None
# 6      Progressive Rock    None    None    None
# 9              Pop Rock    None    None    None
# 17            Hard Rock    None    None    None
# 25             Art Rock    None    None    None
# ...                 ...     ...     ...     ...
# 4983         Samba Soul    None    None    None
# 4985               None    None    None    None
# 4991               Funk    None    None    None
# 4995     Symphonic Prog    None    None    None
# 4999           Pop Soul    None    None    None
#
# [1232 rows x 14 columns]

# %%
df_1970 = df_1970['Genre 1'].value_counts()[:10]
df_1970 = df_1970.to_frame().reset_index()
df_1970 = df_1970.rename(columns = {'index': 'Genre', 'Genre 1': 'Count'})
df_1970
# Out:
#                Genre  Count
# 0   Progressive Rock    156
# 1          Hard Rock     78
# 2  Singer/Songwriter     53
# 3        Jazz Fusion     46
# 4                MPB     40
# 5         Blues Rock     38
# 6     Symphonic Prog     26
# 7       Roots Reggae     26
# 8           Pop Rock     26
# 9           Art Rock     22

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.barplot(x=df_1970['Genre'], y=df_1970['Count'])
plt.title('Top 10 Genres in the 70s', fontsize=20)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.xticks(rotation='70')

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %%
df_1980 = df[df['Release Year'].between(1980, 1989)]
df_1980
# Out:
#       Ranking                          Album  \
# 12       13.0                Remain in Light
# 29       30.0                 Disintegration
# 33       34.0              The Queen Is Dead
# 35       36.0                      Doolittle
# 42       43.0                 Hounds of Love
# ...       ...                            ...
# 4969   4970.0           Speak English or Die
# 4971   4972.0                 Ancient Dreams
# 4980   4981.0                      Fegmania!
# 4986   4987.0  ごはんができたよ (Gohan ga Dekita yo)
# 4993   4994.0               Bring the Family
#
#                             Artist Name  Average Rating Number of Ratings  \
# 12                        Talking Heads            4.25            36,196
# 29                             The Cure            4.17            29,436
# 33                           The Smiths            4.12            35,400
# 35                               Pixies            4.12            34,101
# 42                            Kate Bush            4.15            22,774
# ...                                 ...             ...               ...
# 4969                             S.O.D.            3.64             2,654
# 4971                         Candlemass            3.66             1,920
# 4980  Robyn Hitchcock and The Egyptians            3.68               754
# 4986                  矢野顕子 [Akiko Yano]            3.70               345
# 4993                         John Hiatt            3.68               727
#
#       Number of Reviews  Release Month  Release Year  Release Decade  \
# 12                  520             10          1980            1980
# 29                  413              5          1989            1980
# 33                  530              6          1986            1980
# 35                  548              4          1989            1980
# 42                  266              9          1985            1980
# ...                 ...            ...           ...             ...
# 4969                 67              8          1985            1980
# 4971                 36             11          1988            1980
# 4980                 19              3          1985            1980
# 4986                  5             10          1980            1980
# 4993                 37              5          1987            1980
#
#                      Genre 1           Genre 2           Genre 3 Genre 4  \
# 12                  New Wave         Post-Punk              None    None
# 29               Gothic Rock         Post-Punk              None    None
# 33                Jangle Pop         Indie Pop              None    None
# 35          Alternative Rock        Indie Rock              None    None
# 42                   Art Pop   Progressive Pop              None    None
# ...                      ...               ...               ...     ...
# 4969        Crossover Thrash              None              None    None
# 4971  Traditional Doom Metal   Epic Doom Metal        Doom Metal    None
# 4980         Psychedelic Pop        Jangle Pop   Neo-Psychedelia    None
# 4986         Progressive Pop           Art Pop              None    None
# 4993       Singer/Songwriter        Roots Rock         Americana    None
#
#      Genre 5
# 12      None
# 29      None
# 33      None
# 35      None
# 42      None
# ...      ...
# 4969    None
# 4971    None
# 4980    None
# 4986    None
# 4993    None
#
# [688 rows x 14 columns]

# %%
df_1980 = df_1980['Genre 1'].value_counts()[:10]
df_1980 = df_1980.to_frame().reset_index()
df_1980 = df_1980.rename(columns = {'index': 'Genre', 'Genre 1': 'Count'})
df_1980
# Out:
#                Genre  Count
# 0        Heavy Metal     63
# 1          Post-Punk     54
# 2       Thrash Metal     44
# 3         Film Score     29
# 4           New Wave     27
# 5           Synthpop     20
# 6           Pop Rock     20
# 7         Jangle Pop     17
# 8  Singer/Songwriter     16
# 9          Hard Rock     16

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.barplot(x=df_1980['Genre'], y=df_1980['Count'])
plt.title('Top 10 Genres in the 80s', fontsize=20)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.xticks(rotation='70')

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %%
df_1990 = df[df['Release Year'].between(1990, 1999)]
df_1990
# Out:
#       Ranking                                   Album          Artist Name  \
# 0         1.0                             OK Computer            Radiohead
# 5         6.0                                Loveless  My Bloody Valentine
# 20       21.0                                Illmatic                  Nas
# 22       23.0           In the Aeroplane Over the Sea   Neutral Milk Hotel
# 24       25.0         Enter the Wu-Tang (36 Chambers)         Wu-Tang Clan
# ...       ...                                     ...                  ...
# 4976   4977.0                          Into the Grave                Grave
# 4987   4988.0  Transmissions From the Satellite Heart     The Flaming Lips
# 4990   4991.0                    The Time of the Oath            Helloween
# 4994   4995.0                                 Passion            Catharsis
# 4996   4997.0                    Knights of the Cross         Grave Digger
#
#       Average Rating Number of Ratings  Number of Reviews  Release Month  \
# 0               4.23            70,382               1531              6
# 5               4.24            49,887               1223             11
# 20              4.20            30,886                619              4
# 22              4.09            47,979                968              2
# 24              4.19            27,579                425             11
# ...              ...               ...                ...            ...
# 4976            3.66             1,338                 21              8
# 4987            3.64             5,501                 84              6
# 4990            3.65             1,542                 43              3
# 4994            3.65               616                  6              1
# 4996            3.67               562                 11              5
#
#       Release Year  Release Decade             Genre 1            Genre 2  \
# 0             1997            1990    Alternative Rock           Art Rock
# 5             1991            1990            Shoegaze          Noise Pop
# 20            1994            1990  East Coast Hip Hop           Boom Bap
# 22            1998            1990          Indie Folk         Indie Rock
# 24            1993            1990  East Coast Hip Hop           Boom Bap
# ...            ...             ...                 ...                ...
# 4976          1991            1990         Death Metal               None
# 4987          1993            1990           Noise Pop   Alternative Rock
# 4990          1996            1990         Power Metal               None
# 4994          1999            1990          Crust Punk          Metalcore
# 4996          1998            1990         Power Metal        Heavy Metal
#
#                 Genre 3 Genre 4 Genre 5
# 0                  None    None    None
# 5                  None    None    None
# 20     Hardcore Hip Hop    None    None
# 22                 None    None    None
# 24     Hardcore Hip Hop    None    None
# ...                 ...     ...     ...
# 4976               None    None    None
# 4987               None    None    None
# 4990               None    None    None
# 4994               None    None    None
# 4996               None    None    None
#
# [1080 rows x 14 columns]

# %%
df_1990 = df_1990['Genre 1'].value_counts()[:10]
df_1990 = df_1990.to_frame().reset_index()
df_1990 = df_1990.rename(columns = {'index': 'Genre', 'Genre 1': 'Count'})
df_1990
# Out:
#                 Genre  Count
# 0    Alternative Rock     64
# 1  East Coast Hip Hop     64
# 2         Death Metal     42
# 3   Singer/Songwriter     31
# 4    Video Game Music     30
# 5          Indie Rock     26
# 6   Progressive Metal     23
# 7         Heavy Metal     22
# 8          Film Score     20
# 9             Art Pop     20

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.barplot(x=df_1990['Genre'], y=df_1990['Count'])
plt.title('Top 10 Genres in the 90s', fontsize=20)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.xticks(rotation='70')

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %%
df_2000 = df[df['Release Year'].between(2000, 2009)]
df_2000
# Out:
#       Ranking                                           Album  \
# 3         4.0                                           Kid A
# 11       12.0                                     Madvillainy
# 14       15.0                                     In Rainbows
# 21       22.0  Lift Yr. Skinny Fists Like Antennas to Heaven!
# 52       53.0                                      Vespertine
# ...       ...                                             ...
# 4974   4975.0                                          Litany
# 4978   4979.0                                           Sagas
# 4982   4983.0                              Demons Dance Alone
# 4984   4985.0                                The True Meaning
# 4997   4998.0               (Listen For) The Rag and Bone Man
#
#                       Artist Name  Average Rating Number of Ratings  \
# 3                       Radiohead            4.21            58,590
# 11                     Madvillain            4.26            35,573
# 14                      Radiohead            4.18            48,484
# 21    Godspeed You Black Emperor!            4.17            34,973
# 52                          Björk            4.13            23,181
# ...                           ...             ...               ...
# 4974                        Vader            3.66             1,491
# 4978                  Equilibrium            3.62             1,049
# 4982                The Residents            3.67               651
# 4984                      Cormega            3.70               388
# 4997           And Also the Trees            3.68               524
#
#       Number of Reviews  Release Month  Release Year  Release Decade  \
# 3                   734             10          2000            2000
# 11                  376              3          2004            2000
# 14                  756             10          2007            2000
# 21                  612             10          2000            2000
# 52                  261              8          2001            2000
# ...                 ...            ...           ...             ...
# 4974                 23              5          2000            2000
# 4978                 33              6          2008            2000
# 4982                 15              5          2002            2000
# 4984                  9              6          2002            2000
# 4997                 15             11          2007            2000
#
#                  Genre 1             Genre 2      Genre 3 Genre 4 Genre 5
# 3               Art Rock   Experimental Rock   Electronic    None    None
# 11      Abstract Hip Hop                None         None    None    None
# 14              Art Rock    Alternative Rock         None    None    None
# 21             Post-Rock                None         None    None    None
# 52               Art Pop          Electronic         None    None    None
# ...                  ...                 ...          ...     ...     ...
# 4974         Death Metal                None         None    None    None
# 4978          Folk Metal        Viking Metal         None    None    None
# 4982             Art Pop   Experimental Rock         None    None    None
# 4984  East Coast Hip Hop    Hardcore Hip Hop         None    None    None
# 4997            Art Rock                None         None    None    None
#
# [882 rows x 14 columns]

# %%
df_2000 = df_2000['Genre 1'].value_counts()[:10]
df_2000 = df_2000.to_frame().reset_index()
df_2000 = df_2000.rename(columns = {'index': 'Genre', 'Genre 1': 'Count'})
df_2000
# Out:
#                      Genre  Count
# 0        Progressive Metal     41
# 1        Singer/Songwriter     39
# 2         Video Game Music     32
# 3         Progressive Rock     31
# 4               Indie Rock     31
# 5               Film Score     20
# 6       East Coast Hip Hop     19
# 7              Power Metal     19
# 8         Alternative Rock     18
# 9  Atmospheric Black Metal     16

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.barplot(x=df_2000['Genre'], y=df_2000['Count'])
plt.title('Top 10 Genres in the 00s', fontsize=20)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.xticks(rotation='70')

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %%
df_2010 = df[df['Release Year'].between(2010, 2019)]
df_2010
# Out:
#       Ranking                              Album                 Artist Name  \
# 4         5.0                To Pimp a Butterfly              Kendrick Lamar
# 16       17.0             good kid, m.A.A.d city              Kendrick Lamar
# 26       27.0  My Beautiful Dark Twisted Fantasy                  Kanye West
# 59       60.0                Atrocity Exhibition                 Danny Brown
# 61       62.0                    The Money Store                 Death Grips
# ...       ...                                ...                         ...
# 4949   4950.0                         Saturation                Brockhampton
# 4953   4954.0                         Blood Lust  Uncle Acid & The Deadbeats
# 4955   4956.0                         From Sleep                 Max Richter
# 4988   4989.0                   Abandon All Life                       Nails
# 4992   4993.0          現実を超えて (Genjitsu o koete)    t e l e p a t h テレパシー能力者
#
#       Average Rating Number of Ratings  Number of Reviews  Release Month  \
# 4               4.27            44,206                379              3
# 16              4.20            38,939                315             10
# 26              4.07            48,415                636             11
# 59              4.08            25,353                193              9
# 61              4.02            36,403                311              4
# ...              ...               ...                ...            ...
# 4949            3.55            17,629                 70              6
# 4953            3.66             3,227                 44              5
# 4955            3.68               728                  8              9
# 4988            3.64             3,864                 36              3
# 4992            3.67               814                 13              6
#
#       Release Year  Release Decade               Genre 1  \
# 4             2015            2010     Conscious Hip Hop
# 16            2012            2010    West Coast Hip Hop
# 26            2010            2010               Pop Rap
# 59            2016            2010  Experimental Hip Hop
# 61            2012            2010    Industrial Hip Hop
# ...            ...             ...                   ...
# 4949          2017            2010               Pop Rap
# 4953          2011            2010           Heavy Psych
# 4955          2015            2010       Post-Minimalism
# 4988          2013            2010             Grindcore
# 4992          2014            2010             Vaporwave
#
#                       Genre 2                Genre 3 Genre 4 Genre 5
# 4          West Coast Hip Hop               Jazz Rap    None    None
# 16          Conscious Hip Hop                   None    None    None
# 26                    Hip Hop                   None    None    None
# 59           Hardcore Hip Hop                   None    None    None
# 61           Hardcore Hip Hop   Experimental Hip Hop    None    None
# ...                       ...                    ...     ...     ...
# 4949       West Coast Hip Hop                   None    None    None
# 4953   Traditional Doom Metal                   None    None    None
# 4955         Modern Classical                   None    None    None
# 4988            Powerviolence                   None    None    None
# 4992                     None                   None    None    None
#
# [382 rows x 14 columns]

# %%
df_2010 = df_2010['Genre 1'].value_counts()[:10]
df_2010 = df_2010.to_frame().reset_index()
df_2010 = df_2010.rename(columns = {'index': 'Genre', 'Genre 1': 'Count'})
df_2010
# Out:
#                   Genre  Count
# 0      Video Game Music     30
# 1            Film Score     13
# 2     Progressive Metal     12
# 3               Art Pop     11
# 4    East Coast Hip Hop     10
# 5  Experimental Hip Hop     10
# 6     Singer/Songwriter      9
# 7               Ambient      9
# 8            Indie Rock      8
# 9      Southern Hip Hop      7

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.barplot(x=df_2010['Genre'], y=df_2010['Count'])
plt.title('Top 10 Genres in the 10s', fontsize=20)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.xticks(rotation='70')

for p in ax.patches:
    x = p.get_x() + p.get_width() / 2
    y = p.get_y() + p.get_height() / 1.2
    value = '{:.0f}'.format(p.get_height())
    ax.text(x, y, value,  ha='center', color='white', fontweight='bold', fontsize=15)
    
plt.show()

# %% [markdown]
# ### Rankings of the top genre in each decade

# %%
mean_70 = df[df['Genre 1'] == 'Progressive Rock']['Ranking'].mean()

top5_70 = df[df['Genre 1'] == 'Progressive Rock'][:5]
top5_70[['Ranking', 'Album', 'Artist Name']]
# Out:
#      Ranking                             Album   Artist Name
# 1        2.0                Wish You Were Here    Pink Floyd
# 2        3.0  In the Court of the Crimson King  King Crimson
# 25      26.0                               Red  King Crimson
# 32      33.0                           Animals    Pink Floyd
# 138    139.0                            Meddle    Pink Floyd

# %%
mean_80 = df[df['Genre 1'] == 'Heavy Metal']['Ranking'].mean()

top5_80 = df[df['Genre 1'] == 'Heavy Metal'][:5]
top5_80[['Ranking', 'Album', 'Artist Name']]
# Out:
#      Ranking              Album    Artist Name
# 17      18.0           Paranoid  Black Sabbath
# 51      52.0  Master of Reality  Black Sabbath
# 77      78.0      Black Sabbath  Black Sabbath
# 167    168.0         Powerslave    Iron Maiden
# 171    172.0         Painkiller   Judas Priest

# %%
mean_90 = df[df['Genre 1'] == 'Alternative Rock']['Ranking'].mean()

top5_90 = df[df['Genre 1'] == 'Alternative Rock'][:5]
top5_90[['Ranking', 'Album', 'Artist Name']]
# Out:
#      Ranking          Album                  Artist Name
# 0        1.0    OK Computer                    Radiohead
# 35      36.0      Doolittle                       Pixies
# 163    164.0  Siamese Dream            Smashing Pumpkins
# 186    187.0      The Bends                    Radiohead
# 247    248.0    Let Love In  Nick Cave and The Bad Seeds

# %%
mean_00 = df[df['Genre 1'] == 'Progressive Metal']['Ranking'].mean()

top5_00 = df[df['Genre 1'] == 'Progressive Metal'][:5]
top5_00[['Ranking', 'Album', 'Artist Name']]
# Out:
#      Ranking                Album Artist Name
# 226    227.0      Blackwater Park       Opeth
# 257    258.0           Still Life       Opeth
# 383    384.0       Ghost Reveries       Opeth
# 409    410.0       Crack the Skye    Mastodon
# 544    545.0  From Mars to Sirius      Gojira

# %%
mean_10 = df[df['Genre 1'] == 'Video Game Music']['Ranking'].mean()

top5_10 = df[df['Genre 1'] == 'Video Game Music'][:5]
top5_10[['Ranking', 'Album', 'Artist Name']]
# Out:
#      Ranking                                              Album  \
# 140    141.0                                      Silent Hill 2
# 212    213.0                            Minecraft: Volume Alpha
# 239    240.0                                   "Chrono Trigger"
# 255    256.0          Donkey Kong Country 2: Diddy's Kong Quest
# 261    262.0  ゼルダの伝説: ムジュラの仮面 (The Legend of Zelda: Majora's...
#
#              Artist Name
# 140  山岡晃 [Akira Yamaoka]
# 212                 C418
# 239     Yasunori Mitsuda
# 255           David Wise
# 261    近藤浩治 [Koji Kondo]

# %%
mean_decade_rankings = pd.DataFrame()

# %%
print('Mean Ranking for Progressive Rock:  #', round(mean_70))
print('Mean Ranking for Heavy Metal:  #', round(mean_80))
print('Mean Ranking for Alternative Rock:  #', round(mean_90))
print('Mean Ranking for Progressive Metal:  #', round(mean_00))
print('Mean Ranking for Video Game Music:  #', round(mean_10))
# Out:
# Mean Ranking for Progressive Rock:  # 2926
# Mean Ranking for Heavy Metal:  # 2427
# Mean Ranking for Alternative Rock:  # 2647
# Mean Ranking for Progressive Metal:  # 2760
# Mean Ranking for Video Game Music:  # 1601

# %% [markdown]
# ### Genre impact over time

# %%
prog_rock_years = df[df['Genre 1'] == 'Progressive Rock']
prog_rock_years = prog_rock_years['Release Year'].value_counts()
prog_rock_years = prog_rock_years.to_frame().reset_index()
prog_rock_years = prog_rock_years.rename(columns = {'index': 'Year', 'Release Year': 'Count'})
prog_rock_years
# Out:
#     Year  Count
# 0   1971     24
# 1   1975     22
# 2   1974     22
# 3   1973     19
# 4   1972     18
# 5   1970     15
# 6   1976     15
# 7   1977     10
# 8   1979      7
# 9   2003      7
# 10  2005      6
# 11  2007      5
# 12  1969      5
# 13  1978      4
# 14  2004      3
# 15  2000      3
# 16  1998      3
# 17  1996      3
# 18  1994      3
# 19  2009      3
# 20  1981      3
# 21  2013      2
# 22  1980      2
# 23  2006      2
# 24  1984      2
# 25  1995      2
# 26  1999      2
# 27  2002      2
# 28  1992      2
# 29  2015      1
# 30  1982      1
# 31  1988      1
# 32  1990      1
# 33  2014      1
# 34  1993      1
# 35  1997      1
# 36  2012      1
# 37  1968      1

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.lineplot(x=prog_rock_years['Year'], y=prog_rock_years['Count'])
plt.title('Count of Progressive Rock Albums over the Years', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.show()

# %%
heavy_metal_years = df[df['Genre 1'] == 'Heavy Metal']
heavy_metal_years = heavy_metal_years['Release Year'].value_counts()
heavy_metal_years = heavy_metal_years.to_frame().reset_index()
heavy_metal_years = heavy_metal_years.rename(columns = {'index': 'Year', 'Release Year': 'Count'})
heavy_metal_years
# Out:
#     Year  Count
# 0   1984     11
# 1   1986     10
# 2   1988      8
# 3   1989      8
# 4   1983      7
# 5   1987      5
# 6   1982      4
# 7   1980      4
# 8   1992      4
# 9   1991      4
# 10  1990      4
# 11  1981      3
# 12  2000      3
# 13  1993      3
# 14  2004      3
# 15  1979      3
# 16  1985      3
# 17  1970      2
# 18  1994      2
# 19  1995      2
# 20  1997      2
# 21  2003      2
# 22  2007      1
# 23  1998      1
# 24  2006      1
# 25  1978      1
# 26  1977      1
# 27  1976      1
# 28  1975      1
# 29  1973      1
# 30  1972      1
# 31  1971      1
# 32  2013      1

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.lineplot(x=heavy_metal_years['Year'], y=heavy_metal_years['Count'])
plt.title('Count of Heavy Metal Albums over the Years', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.show()

# %%
alt_rock_years = df[df['Genre 1'] == 'Alternative Rock']
alt_rock_years = alt_rock_years['Release Year'].value_counts()
alt_rock_years = alt_rock_years.to_frame().reset_index()
alt_rock_years = alt_rock_years.rename(columns = {'index': 'Year', 'Release Year': 'Count'})
alt_rock_years
# Out:
#     Year  Count
# 0   1994     10
# 1   1996     10
# 2   1995      8
# 3   1999      7
# 4   1998      7
# 5   1992      6
# 6   1993      5
# 7   1990      5
# 8   1997      4
# 9   2001      4
# 10  2004      4
# 11  1987      4
# 12  2003      3
# 13  2000      3
# 14  1991      2
# 15  1985      2
# 16  1989      1
# 17  1988      1
# 18  2013      1
# 19  2011      1
# 20  2002      1
# 21  2005      1
# 22  2006      1
# 23  2008      1
# 24  1984      1

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.lineplot(x=alt_rock_years['Year'], y=alt_rock_years['Count'])
plt.title('Count of Alternative Rock Albums over the Years', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.show()

# %%
prog_metal_years = df[df['Genre 1'] == 'Progressive Metal']
prog_metal_years = prog_metal_years['Release Year'].value_counts()
prog_metal_years = prog_metal_years.to_frame().reset_index()
prog_metal_years = prog_metal_years.rename(columns = {'index': 'Year', 'Release Year': 'Count'})
prog_metal_years
# Out:
#     Year  Count
# 0   2001      8
# 1   2004      5
# 2   1997      5
# 3   2000      5
# 4   2002      5
# 5   2011      4
# 6   2009      4
# 7   2008      4
# 8   1999      4
# 9   1993      3
# 10  1996      3
# 11  2003      3
# 12  2006      3
# 13  2005      2
# 14  2007      2
# 15  1998      2
# 16  2010      2
# 17  2012      2
# 18  2013      2
# 19  1992      2
# 20  1991      2
# 21  1989      1
# 22  1986      1
# 23  1988      1
# 24  2015      1
# 25  1990      1
# 26  1994      1
# 27  2014      1
# 28  1985      1

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.lineplot(x=prog_metal_years['Year'], y=prog_metal_years['Count'])
plt.title('Count of Progressive Metal Albums over the Years', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.show()

# %%
video_game_years = df[df['Genre 1'] == 'Video Game Music']
video_game_years = video_game_years['Release Year'].value_counts()
video_game_years = video_game_years.to_frame().reset_index()
video_game_years = video_game_years.rename(columns = {'index': 'Year', 'Release Year': 'Count'})
video_game_years
# Out:
#     Year  Count
# 0   1998      9
# 1   2011      6
# 2   2017      5
# 3   1999      5
# 4   2001      5
# 5   2006      4
# 6   2000      4
# 7   2002      4
# 8   2003      4
# 9   2010      4
# 10  2004      4
# 11  1995      4
# 12  1994      3
# 13  1997      3
# 14  2008      3
# 15  1991      3
# 16  2015      3
# 17  2016      3
# 18  2020      2
# 19  2009      2
# 20  2012      2
# 21  2014      2
# 22  2018      2
# 23  2019      2
# 24  1996      2
# 25  1993      1
# 26  2021      1
# 27  2005      1
# 28  2007      1
# 29  2013      1
# 30  1989      1

# %%
fig, ax = plt.subplots(figsize=(14,10))
sns.lineplot(x=video_game_years['Year'], y=video_game_years['Count'])
plt.title('Count of Video Game Music Albums over the Years', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Count', fontsize=15)
plt.show()

# %% [markdown]
# ### Artists

# %%
df['Artist Name'].value_counts()[0:5]
# Out:
# Various Artists    25
# Miles Davis        17
# John Coltrane      14
# Tom Waits          13
# John Williams      12
# Name: Artist Name, dtype: int64

# %%
df['Artist Name'].value_counts()[1:6]
# Out:
# Miles Davis      17
# John Coltrane    14
# Tom Waits        13
# John Williams    12
# Bob Dylan        11
# Name: Artist Name, dtype: int64

# %%
miles_davis = df[df['Artist Name'] == 'Miles Davis'][['Artist Name','Album','Release Year', 'Ranking']]
miles_davis
# Out:
#       Artist Name                      Album  Release Year  Ranking
# 18    Miles Davis               Kind of Blue          1959     19.0
# 37    Miles Davis            In a Silent Way          1969     38.0
# 47    Miles Davis               Bitches Brew          1970     48.0
# 203   Miles Davis             Get Up With It          1974    204.0
# 215   Miles Davis  A Tribute to Jack Johnson          1971    216.0
# 370   Miles Davis              On the Corner          1972    371.0
# 539   Miles Davis          Sketches of Spain          1960    540.0
# 897   Miles Davis      'Round About Midnight          1957    898.0
# 981   Miles Davis  Ascenseur pour l'échafaud          1958    982.0
# 1089  Miles Davis                  Nefertiti          1968   1090.0
# 1102  Miles Davis                 Milestones          1958   1103.0
# 1395  Miles Davis                    Big Fun          1974   1396.0
# 1399  Miles Davis      Filles de Kilimanjaro          1969   1400.0
# 1990  Miles Davis                     E.S.P.          1965   1991.0
# 3077  Miles Davis             Porgy and Bess          1959   3078.0
# 4126  Miles Davis                   Sorcerer          1967   4127.0
# 4456  Miles Davis           Miles in the Sky          1968   4457.0

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x=miles_davis['Release Year'], y = miles_davis['Ranking'], 
                     hue = miles_davis['Album'], s = 200, alpha=0.7)
ax.invert_yaxis()
plt.legend(markerscale=2, bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0)
plt.title("Ranking of Miles Davis Albums over the Years", fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Ranking', fontsize=15)
# Out:
# Text(0, 0.5, 'Album Ranking')

# %%
john_coltrane = df[df['Artist Name'] == 'John Coltrane'][['Artist Name','Album','Release Year', 'Ranking']]
john_coltrane
# Out:
#         Artist Name                   Album  Release Year  Ranking
# 15    John Coltrane          A Love Supreme          1965     16.0
# 98    John Coltrane             Giant Steps          1960     99.0
# 111   John Coltrane      My Favorite Things          1961    112.0
# 176   John Coltrane              Blue Train          1958    177.0
# 263   John Coltrane   Ascension [Edition I]          1966    264.0
# 289   John Coltrane            Olé Coltrane          1961    290.0
# 520   John Coltrane             Meditations          1966    521.0
# 561   John Coltrane                Sun Ship          1971    562.0
# 655   John Coltrane  Ascension [Edition II]          1966    656.0
# 1472  John Coltrane      Interstellar Space          1974   1473.0
# 1872  John Coltrane        Coltrane's Sound          1964   1873.0
# 1978  John Coltrane              Transition          1970   1979.0
# 2152  John Coltrane            Kulu Sé Mama          1967   2153.0
# 4019  John Coltrane              Expression          1967   4020.0

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x=john_coltrane['Release Year'], y = john_coltrane['Ranking'],
                     hue = john_coltrane['Album'], s = 200, alpha=0.7)
ax.invert_yaxis()
plt.legend(markerscale=2, bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0)
plt.title("Ranking of John Coltrane Albums over the Years", fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Ranking', fontsize=15)
# Out:
# Text(0, 0.5, 'Album Ranking')

# %%
tom_waits = df[df['Artist Name'] == 'Tom Waits'][['Artist Name','Album','Release Year', 'Ranking']]
tom_waits
# Out:
#      Artist Name                                  Album  Release Year  Ranking
# 88     Tom Waits                              Rain Dogs          1985     89.0
# 198    Tom Waits                     Swordfishtrombones          1983    199.0
# 242    Tom Waits                           Bone Machine          1992    243.0
# 491    Tom Waits  Orphans: Brawlers, Bawlers & Bastards          2006    492.0
# 691    Tom Waits                        Mule Variations          1999    692.0
# 930    Tom Waits                           Closing Time          1973    931.0
# 1216   Tom Waits                      Franks Wild Years          1987   1217.0
# 1334   Tom Waits                           Small Change          1976   1335.0
# 1445   Tom Waits                                  Alice          2002   1446.0
# 1550   Tom Waits                            Blood Money          2002   1551.0
# 2185   Tom Waits                         Blue Valentine          1978   2186.0
# 3734   Tom Waits            The Heart of Saturday Night          1974   3735.0
# 3913   Tom Waits                              Real Gone          2004   3914.0

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x=tom_waits['Release Year'], y = tom_waits['Ranking'],
                     hue = tom_waits['Album'], s = 200, alpha=0.7)
ax.invert_yaxis()
plt.legend(markerscale=2, bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0)
plt.title("Ranking of Tom Waits Albums over the Years", fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Ranking', fontsize=15)
# Out:
# Text(0, 0.5, 'Album Ranking')

# %%
john_williams = df[df['Artist Name'] == 'John Williams'][['Artist Name','Album','Release Year', 'Ranking']]
john_williams
# Out:
#         Artist Name                                       Album  Release Year  \
# 322   John Williams          Star Wars: The Empire Strikes Back          1980
# 1139  John Williams               Star Wars: Return of the Jedi          1983
# 1237  John Williams                            Schindler's List          1993
# 1313  John Williams                     Raiders of the Lost Ark          1981
# 1720  John Williams  Star Wars Episode III: Revenge of the Sith          2005
# 2046  John Williams                               Jurassic Park          1993
# 2524  John Williams                  E.T. the Extra-Terrestrial          1982
# 2690  John Williams          Close Encounters of the Third Kind          1977
# 2986  John Williams          Indiana Jones and the Last Crusade          1989
# 3118  John Williams    Harry Potter and the Prisoner of Azkaban          2004
# 3779  John Williams                                        Jaws          1975
# 4600  John Williams     Star Wars Episode I: The Phantom Menace          1999
#
#       Ranking
# 322     323.0
# 1139   1140.0
# 1237   1238.0
# 1313   1314.0
# 1720   1721.0
# 2046   2047.0
# 2524   2525.0
# 2690   2691.0
# 2986   2987.0
# 3118   3119.0
# 3779   3780.0
# 4600   4601.0

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x=john_williams['Release Year'], y = john_williams['Ranking'],
                     hue = john_williams['Album'], s = 200, alpha=0.7)
ax.invert_yaxis()
plt.legend(markerscale=2, bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0)
plt.title("Ranking of John Williams Albums over the Years", fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Ranking', fontsize=15)
# Out:
# Text(0, 0.5, 'Album Ranking')

# %%
bob_dylan = df[df['Artist Name'] == 'Bob Dylan'][['Artist Name','Album','Release Year', 'Ranking']]
bob_dylan
# Out:
#      Artist Name                          Album  Release Year  Ranking
# 34     Bob Dylan           Highway 61 Revisited          1965     35.0
# 43     Bob Dylan               Blonde on Blonde          1966     44.0
# 48     Bob Dylan            Blood on the Tracks          1975     49.0
# 80     Bob Dylan      Bringing It All Back Home          1965     81.0
# 194    Bob Dylan     The Freewheelin' Bob Dylan          1963    195.0
# 459    Bob Dylan                         Desire          1976    460.0
# 1217   Bob Dylan               Time Out of Mind          1997   1218.0
# 1240   Bob Dylan  The Times They Are A-Changin'          1964   1241.0
# 1354   Bob Dylan            John Wesley Harding          1967   1355.0
# 2412   Bob Dylan      Another Side of Bob Dylan          1964   2413.0
# 4279   Bob Dylan               "Love and Theft"          2001   4280.0

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x=bob_dylan['Release Year'], y = bob_dylan['Ranking'],
                     hue = bob_dylan['Album'], s = 200, alpha=0.7)
ax.invert_yaxis()
plt.legend(markerscale=2, bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0)
plt.title("Ranking of Bob Dylan Albums over the Years", fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Album Ranking', fontsize=15)
# Out:
# Text(0, 0.5, 'Album Ranking')
